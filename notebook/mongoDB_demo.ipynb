# %% [markdown]
# # **_MongoDB Setup and Demo_**

# %% [markdown]
# ___

# %% [markdown]
# - the data is in local
# - but we will not be working with the lcoal data
# - we want ot fetch it from a database that we have set on mongoDB
# - but before we pull the data from mongoDB, we will first have to push the data into the database
# - and thus this file

# %% [markdown]
# ___

# %%
import pandas as pd
import pymongo

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %% [markdown]
# ## **_The df should be converted into a dictionary before we push it to mongoDB_**

# %% [markdown]
# ### **why?**
# - because mongoDB is a NoSQL database, and the items are stored as key-value pairs ---> therefore dictionary

# %%
data = df.to_dict(orient='records')

# %% [markdown]
# Username: Achyuth_mlops_user
# Password: Iu6mo7qIJmqRnfAU

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://Achyuth_mlops_user:Iu6mo7qIJmqRnfAU@cluster0.72vxxxt.mongodb.net/?appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %% [markdown]
# # **_Uploading the data to MongoDB_**

# %%
rec = collection.insert_many(data)

# %%
print(type(rec))
# Out:
# <class 'pymongo.results.InsertManyResult'>

# %%
records = collection.find()
records

# %% [markdown]
# # **Data successfully added to the MongoDB database**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ___

# %% [markdown]
# ___
